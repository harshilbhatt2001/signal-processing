# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from scipy import signal, fftpack
import pandas as pd

# %%
plt.rcParams["figure.figsize"] = (15,6)

# %%
df = pd.read_csv(r'data\Raw_Data.csv')
time = df['Time (s)'].to_numpy()
df.set_index('Time (s)', inplace=True)
df
# Out:
#            Linear Acceleration x (m/s^2)  Linear Acceleration y (m/s^2)  \
# Time (s)
# 0.000000                       -0.001757                       0.020748
# 0.010073                       -0.002605                      -0.002677
# 0.020133                        0.000448                       0.014517
# 0.030207                       -0.000398                       0.034615
# 0.040280                        0.000198                       0.038046
# ...                                  ...                            ...
# 29.837565                      -0.031471                       0.040796
# 29.847638                      -0.005681                       0.084515
# 29.857712                       0.034258                       0.097885
# 29.867804                       0.028842                       0.090711
# 29.877878                       0.000701                       0.103458
#
#            Linear Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# Time (s)
# ...

# %%
df.plot(y="Linear Acceleration x (m/s^2)");

# %%
df.plot(y="Linear Acceleration y (m/s^2)");

# %%
df.plot(y="Linear Acceleration z (m/s^2)");

# %%
df.plot(y="Absolute acceleration (m/s^2)");

# %%
fs = 1/0.010073
fhp = signal.cheby2(N=20, rs=180, Wn=3, fs=fs, btype='hp', output='sos')

# %%
df['filtered_x'] = signal.sosfilt(fhp, df['Linear Acceleration x (m/s^2)'])
df.plot(y=["Linear Acceleration x (m/s^2)", "filtered_x"]);

# %%
df['filtered_abs'] = signal.sosfilt(fhp, df['Absolute acceleration (m/s^2)'])
df.plot(y=["Absolute acceleration (m/s^2)", "filtered_abs"]);

# %%
freqs, psd = signal.welch(df['filtered_abs'], fs=fs)

plt.semilogx(freqs, psd)
plt.title('PSD: power spectral density')
plt.xlabel('Frequency')
plt.ylabel('Power')
plt.tight_layout()
